# %%
import matplotlib.pyplot as plt
import numpy as np

# Создаем данные
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Рисуем данные
plt.plot(x, y, label='sin(x)')

# Отобразим график
plt.legend()
plt.ylabel("Membership")
plt.xlabel("Value")
plt.grid(True)
plt.show()
